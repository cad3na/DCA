# %%
# %matplotlib inline
from matplotlib.pyplot import plot, figure, gca

# %%
from control import tf, bode, nyquist, rlocus

# %%
from numpy import linspace

# %%
sistema = tf([0, 0, 1], [1, 1, 0])

# %%
figure(figsize=(10, 10))
mag, phase, omega = bode(sistema)

# %%
figure(figsize=(10, 10))
real, imag, freq = nyquist(sistema)

# %%
T1 = 1
T2 = 2

# %%
sistema = tf([0, 0, 1], [0, T1, 1])*tf([0, 0, 1], [0, T2, 1])*tf([0, 0, 1], [0, 1, 0])

# %%
figure(figsize=(10, 10))
r, k = rlocus(sistema)
ax = gca()
ax.set_xlim(-2.0, 1.0)
ax.set_ylim(-4.0, 4.0);

# %%
figure(figsize=(10, 10))
real, imag, freq = nyquist(sistema)
ax = gca()
ax.set_xlim(-3.0, 0.5)
ax.set_ylim(-1.5, 1.5);

# %%
figure(figsize=(10, 10))
real, imag, freq = nyquist(tf([3],[1])*sistema)
ax = gca()
ax.set_xlim(-3.0, 0.5)
ax.set_ylim(-1.5, 1.5);

# %%
sistema = tf([1, 3], [1, -1]) * tf([0, 1], [1, 0])

# %%
figure(figsize=(10, 10))
r, k = rlocus(sistema, linspace(0, 100, 10000))
ax = gca()
ax.set_xlim(-8.0, 2.0)
ax.set_ylim(-5.0, 5.0);

# %%
figure(figsize=(10, 10))
real, imag, freq = nyquist(sistema)
ax = gca()
ax.set_xlim(-3.0, 0.5)
ax.set_ylim(-3.0, 3.0);

# %%
figure(figsize=(10, 10))
real, imag, freq = nyquist(tf([2],[1])*sistema)
ax = gca()
ax.set_xlim(-3.0, 0.5)
ax.set_ylim(-3.0, 3.0);
