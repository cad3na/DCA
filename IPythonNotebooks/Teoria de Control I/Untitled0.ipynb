# %%
from sympy import init_printing, var, Matrix
init_printing()

# %%
var("a:4")
var("b:4")
var("s:3")
var("r:3")
var("q:6");

# %%
S = Matrix([[1, 0, 0, b0, 0, 0],
            [a1,  1, 0, b1, b0, 0],
            [a2, a1, 1, b2, b1, b0],
            [a3, a2, a1, b3, b2, b1],
            [0, a3, a2, 0, b3, b2],
            [0, 0, a3, 0, 0, b3]])
S
# Out:
# ⎡1   0   0   b₀  0   0 ⎤
# ⎢                      ⎥
# ⎢a₁  1   0   b₁  b₀  0 ⎥
# ⎢                      ⎥
# ⎢a₂  a₁  1   b₂  b₁  b₀⎥
# ⎢                      ⎥
# ⎢a₃  a₂  a₁  b₃  b₂  b₁⎥
# ⎢                      ⎥
# ⎢0   a₃  a₂  0   b₃  b₂⎥
# ⎢                      ⎥
# ⎣0   0   a₃  0   0   b₃⎦

# %%
Sm1 = S.inv()

# %%
Sm1.simplify()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-091d7f3b6325> in <module>()
# ----> 1 Sm1.simplify()
#
# /Users/roberto/miniconda/lib/python2.7/site-packages/sympy/matrices/dense.pyc in simplify(self, ratio, measure)
#     944         for i in range(len(self._mat)):
#     945             self._mat[i] = _simplify(self._mat[i], ratio=ratio,
# --> 946                                      measure=measure)
#     947
#     948     def fill(self, value):
#
# /Users/roberto/miniconda/lib/python2.7/site-packages/sympy/simplify/simplify.pyc in simplify(expr, ratio, measure, fu)
#    3683     expr = bottom_up(expr, lambda w: w.normal())
#    3684     expr = Mul(*powsimp(expr).as_content_primitive())
# -> 3685     _e = cancel(expr)
#    3686     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 3730
# ...
